# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Merges Dyas's dataframe and mine to create a Mega Dataframe

# %%
nbaDyas = pd.read_csv('nba_h2o.csv')

# %%
nbaDyas.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        date start_time              vis_team  \
# 0           0             0  2019-10-22   20:00:00  New Orleans Pelicans
# 1           1             1  2019-10-22   22:30:00    Los Angeles Lakers
# 2           2             2  2019-10-23   19:00:00         Chicago Bulls
# 3           3             3  2019-10-23   19:00:00       Detroit Pistons
# 4           4             4  2019-10-23   19:00:00   Cleveland Cavaliers
#
#               home_team  vis_points  home_points  ot  attendance  ...  \
# 0       Toronto Raptors         122          130   1       20787  ...
# 1  Los Angeles Clippers         102          112   0       19068  ...
# 2     Charlotte Hornets         125          126   0       15424  ...
# 3        Indiana Pacers         119          110   0       17923  ...
# 4         Orlando Magic          85           94   0       18846  ...
#
#   recovery_time perform def_perf_home off_perf_home def_perf_vis off_perf_vis  \
# ...

# %%
nbaDyas = nbaDyas.drop(columns=['Unnamed: 0','Unnamed: 0.1'])
nbaDyas.head()
# Out:
#          date start_time              vis_team             home_team  \
# 0  2019-10-22   20:00:00  New Orleans Pelicans       Toronto Raptors
# 1  2019-10-22   22:30:00    Los Angeles Lakers  Los Angeles Clippers
# 2  2019-10-23   19:00:00         Chicago Bulls     Charlotte Hornets
# 3  2019-10-23   19:00:00       Detroit Pistons        Indiana Pacers
# 4  2019-10-23   19:00:00   Cleveland Cavaliers         Orlando Magic
#
#    vis_points  home_points  ot  attendance home_initial vis_initial  ...  \
# 0         122          130   1       20787          TOR         NOP  ...
# 1         102          112   0       19068          LAC         LAL  ...
# 2         125          126   0       15424          CHO         CHI  ...
# 3         119          110   0       17923          IND         DET  ...
# 4          85           94   0       18846          ORL         CLE  ...
#
#   recovery_time perform def_perf_home off_perf_home def_perf_vis  \
# ...

# %%
nba = pd.read_csv('nba_split_temp_miles.csv')
nba.head()
# Out:
#          date start_time              vis_team             home_team  \
# 0  2019-10-22   20:00:00  New Orleans Pelicans       Toronto Raptors
# 1  2019-10-22   22:30:00    Los Angeles Lakers  Los Angeles Clippers
# 2  2019-10-23   19:00:00         Chicago Bulls     Charlotte Hornets
# 3  2019-10-23   19:00:00       Detroit Pistons        Indiana Pacers
# 4  2019-10-23   19:00:00   Cleveland Cavaliers         Orlando Magic
#
#    vis_points  home_points  ot  attendance home_initial vis_initial  ...  \
# 0         122          130   1       20787          TOR         NOP  ...
# 1         102          112   0       19068          LAC         LAL  ...
# 2         125          126   0       15424          CHO         CHI  ...
# 3         119          110   0       17923          IND         DET  ...
# 4          85           94   0       18846          ORL         CLE  ...
#
#                hp1               hp2               hp3                hp4  \
# ...

# %%
nbamerge = pd.merge(nbaDyas,nba)

# %%
nbamerge.to_csv('nbafull.csv',index=False)
